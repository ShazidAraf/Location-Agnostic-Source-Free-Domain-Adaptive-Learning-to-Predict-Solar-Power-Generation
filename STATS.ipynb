# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.load('data/CA/train.npy',allow_pickle=True)

print(data.shape)
  
(n, bins, patches) = plt.hist(data[:,-1], edgecolor="red", bins=5)
plt.xlabel('Generated Solar Power (kW)',fontsize = 15)
plt.ylabel('Number of occurances',fontsize = 15)
print(bins)
plt.savefig('hist.png')
plt.show()
# Out:
# (14016, 16)
# [ 0.          9.65666667 19.31333333 28.97       38.62666667 48.28333333]

# %%
n
# Out:
# array([2300.,  294.,  364.,  342.,  204.])

# %%
bins
# Out:
# array([0.0, 7.8966666666666665, 15.793333333333333, 23.689999999999998,
#        31.586666666666666, 39.483333333333334], dtype=object)

# %%
patches
# Out:
# <BarContainer object of 5 artists>

# %%
data_bin = [0.0, 7.8966666666666665, 15.793333333333333, 23.689999999999998,31.586666666666666, 39.483333333333334]

y = 55
n_bin = len(data_bin) - 1 

# Categorizing Target Variable
for i in range(len(data_bin)-1):
    if data_bin[i]<=y and data_bin[i+1]>y:
        break

class_label = i
# if y>data_bin[-1]:
    
#     class_label = len(data_bin) - 2


print(class_label)
# Out:
# 4

# %%
len(data_bin)
# Out:
# 1

# %%
i
# Out:
# 4
